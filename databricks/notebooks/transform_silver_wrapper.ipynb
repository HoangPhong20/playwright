# %%
import sys

dbutils.widgets.text('project_root', '', 'Workspace path containing agoda_etl')
dbutils.widgets.text('manifest_path', '', 'Manifest path')
project_root = dbutils.widgets.get('project_root').strip()
manifest_path = dbutils.widgets.get('manifest_path').strip()

if not project_root or not manifest_path:
    raise ValueError('Set project_root and manifest_path before running this notebook')

sys.path.insert(0, project_root)
from agoda_etl import config
from agoda_etl.silver import run_silver_transformation

# %%
result = run_silver_transformation(spark, manifest_path)
if result['status'] != 'success':
    raise RuntimeError(result)

print(result)
display(spark.table(config.SILVER_TABLE).where(
    "batch_id = '{}'".format(result['batch_id'].replace("'", "''"))
).limit(20))
